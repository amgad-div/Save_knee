# %% [markdown]
# # Knee Osteoarthritis with Severity Grading Model

# %% [markdown]
# ## Get data from google drive

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
data_path = '/content/gdrive/MyDrive/DataSets/Knee/knee-osteoarthritis-dataset-with-severity.zip'
import zipfile 
zip_ref = zipfile.ZipFile(data_path)
zip_ref.extractall()
zip_ref.close()

# %%
# count images in train dir 
import os 
train_path = '/content/train'
test_path = '/content/test'
val_path = '/content/val'

# train 
print('train :\n')
for dirpath, dirname, filename in os.walk(train_path):
  print(f'There are {len(dirname)} dirctory and {len(filename)} images in "{dirpath}" . ')
print('\ntest :\n')

# test 
for dirpath, dirname, filename in os.walk(test_path):
  print(f'There are {len(dirname)} dirctory and {len(filename)} images in "{dirpath}" . ')
print('\nval :\n')

# val 
for dirpath, dirname, filename in os.walk(val_path):
  print(f'There are {len(dirname)} dirctory and {len(filename)} images in "{dirpath}" . ')
# Out:
# train :
#
# There are 5 dirctory and 0 images in "/content/train" .
# There are 0 dirctory and 173 images in "/content/train/4" .
# There are 0 dirctory and 2286 images in "/content/train/0" .
# There are 0 dirctory and 757 images in "/content/train/3" .
# There are 0 dirctory and 1516 images in "/content/train/2" .
# There are 0 dirctory and 1046 images in "/content/train/1" .
#
# test :
#
# There are 5 dirctory and 0 images in "/content/test" .
# There are 0 dirctory and 51 images in "/content/test/4" .
# There are 0 dirctory and 639 images in "/content/test/0" .
# There are 0 dirctory and 223 images in "/content/test/3" .
# There are 0 dirctory and 447 images in "/content/test/2" .
# There are 0 dirctory and 296 images in "/content/test/1" .
#
# val :
#
# There are 5 dirctory and 0 images in "/content/val" .
# There are 0 dirctory and 27 images in "/content/val/4" .
# There are 0 dirctory and 328 images in "/content/val/0" .
# There are 0 dirctory and 106 images in "/content/val/3" .
# There are 0 dirctory and 212 images in "/content/val/2" .
# There are 0 dirctory and 153 images in "/content/val/1" .

# %% [markdown]
# ## import library we need

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

# %%
# this cell for define labels and count number of image in each class 
list_of_classes=['Healthy', 'Doubtful', 'Minimal', 'Moderate', 'Severe'] # define class names

classlist=os.listdir(train_path) # this fun list names of all files in directory 
# print(classlist)   
for klass in classlist: # for in ['1', '4', '2', '3', '0']
  # print(klass)
    intklass=int(klass)
    label=list_of_classes[intklass]
    print(label)
    classpath=os.path.join(train_path, klass)
    print(classpath)
    flist=os.listdir(classpath) 
    print(len(flist))
# Out:
# Severe
# /content/train/4
# 173
# Healthy
# /content/train/0
# 2286
# Moderate
# /content/train/3
# 757
# Minimal
# /content/train/2
# 1516
# Doubtful
# /content/train/1
# 1046

# %% [markdown]
# ## Craete DataFrame and insert image with labels

# %%
# define directory path 
train_path = train_path
test_path = test_path
valid_path = val_path

# define the class_names
list_of_classes=['Healthy', 'Doubtful', 'Minimal', 'Moderate', 'Severe']


for d in [train_path, test_path, valid_path]:
    filepaths = []
    labels=[] 
    classlist=os.listdir(d)
       
    for klass in classlist: # for in ['1', '4', '2', '3', '0']
        intklass=int(klass) # convert string to integer 
        label=list_of_classes[intklass]
        classpath=os.path.join(d, klass)
        flist=os.listdir(classpath) # open directory one for example    
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(label)
    Fseries=pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')        
    pdf=pd.concat([Fseries, Lseries], axis=1)
    if d == test_path:
        test_df=pdf
    elif d == valid_path:
        valid_df=pdf
    else:
        train_df=pdf
print('train_df lenght: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# get the number of classes and the images count for each class in train_df
classes=sorted(list(train_df['labels'].unique()))
class_count = len(classes)
print('The number of classes in the dataset is: ', class_count)
groups=train_df.groupby('labels')
print('{0:^30s} {1:^13s}'.format('CLASS', 'IMAGE COUNT'))
countlist=[]
classlist=[]
for label in sorted(list(train_df['labels'].unique())):
    group=groups.get_group(label)
    countlist.append(len(group))
    classlist.append(label)
    print('{0:^30s} {1:^13s}'.format(label, str(len(group))))

# get the classes with the minimum and maximum number of train images
max_value=np.max(countlist)
max_index=countlist.index(max_value)
max_class=classlist[max_index]
min_value=np.min(countlist)
min_index=countlist.index(min_value)
min_class=classlist[min_index]
print(max_class, ' has the most images= ',max_value, ' ', min_class, ' has the least images= ', min_value)
# lets get the average height and width of a sample of the train images
ht=0
wt=0
# select 100 random samples of train_df
train_df_sample=train_df.sample(n=100, random_state=123,axis=0)
for i in range (len(train_df_sample)):
    fpath=train_df_sample['filepaths'].iloc[i]
    img=plt.imread(fpath)
    shape=img.shape
    ht += shape[0]
    wt += shape[1]
print('average height= ', ht//100, ' average width= ', wt//100, 'aspect ratio= ', ht/wt)
# Out:
# train_df lenght:  5778   test_df length:  1656   valid_df length:  826
# The number of classes in the dataset is:  5
#             CLASS               IMAGE COUNT
#            Doubtful                1046
#            Healthy                 2286
#            Minimal                 1516
#            Moderate                 757
#             Severe                  173
# Healthy  has the most images=  2286   Severe  has the least images=  173
# average height=  224  average width=  224 aspect ratio=  1.0

# %% [markdown]
# ## make train_df so no class has more than 500 image samples

# %%
def trim(df, max_samples, min_samples, column):
    df=df.copy()
    groups=df.groupby(column)    
    trimmed_df = pd.DataFrame(columns = df.columns)
    groups=df.groupby(column)
    for label in df[column].unique(): 
        group=groups.get_group(label)
        count=len(group)    
        if count > max_samples:
            sampled_group=group.sample(n=max_samples, random_state=123,axis=0)
            trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
        else:
            if count>=min_samples:
                sampled_group=group        
                trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
    print('after trimming, the maximum samples in any class is now ',max_samples, ' and the minimum samples in any class is ', min_samples)
    return trimmed_df

max_samples=500 # since each class has more than 200 images all classes will be trimmed to have 200 images per class
min_samples=173
column='labels'
train_df= trim(train_df, max_samples, min_samples, column)
# Out:
# after trimming, the maximum samples in any class is now  500  and the minimum samples in any class is  173

# %% [markdown]
# ## Balance train_df so each class has 500 images using augmentation

# %%
for dirpath, dirname, filename in os.walk('/content/aug/Severe'):
  print(f'there are {len(dirname)} directory and {len(filename)} images in {dirpath}')

# %%
import shutil
def balance(df, n, working_dir, img_size):
    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)        
    for label in df['labels'].unique():    
        dir_path=os.path.join(aug_dir,label)    
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images  
    total=0
    gen=ImageDataGenerator(horizontal_flip=True,  rotation_range=20, width_shift_range=.2,
                                  height_shift_range=.2, zoom_range=.2)
    groups=df.groupby('labels') # group by class
    for label in df['labels'].unique():  # for every class               
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label 
        sample_count=len(group)   # determine how many samples there are in this class  
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='filepaths', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False, 
                                            save_to_dir=target_dir, save_prefix='aug-', color_mode='rgb',
                                            save_format='jpg')
            while aug_img_count<delta:
                images=next(aug_gen)            
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=os.listdir(aug_dir)
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)     
        flist=os.listdir(classpath)    
        for f in flist:        
            fpath=os.path.join(classpath,f)         
            aug_fpaths.append(fpath)
            aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='filepaths')
    Lseries=pd.Series(aug_labels, name='labels')
    aug_df=pd.concat([Fseries, Lseries], axis=1)         
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df 

n=600 # number of samples in each class
working_dir=r'./' # directory to store augmented images
img_size=(224,224) # size of augmented images
train_df=balance(train_df, n, working_dir, img_size)
# Out:
# Initial length of dataframe is  2173
# Found 173 validated image filenames.
# Found 500 validated image filenames.
# Found 500 validated image filenames.
# Found 500 validated image filenames.
# Found 500 validated image filenames.
# Total Augmented images created=  827
# Length of augmented dataframe is now  3000

# %% [markdown]
# ## Create the train_gen, test_gen final_test_gen and valid_gen

# %%
batch_size=20 # We will use and EfficientetB3 model, with image size of (200, 250) this size should not cause resource error
trgen=ImageDataGenerator(horizontal_flip=True,rotation_range=20 )
t_and_v_gen=ImageDataGenerator()
msg='{0:70s} for train generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
msg='{0:70s} for valid generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
# this insures that we go through all the sample in the test set exactly once.
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
msg='{0:70s} for test generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
# from the generator we can get information we will need later
classes=list(train_gen.class_indices.keys())
class_indices=list(train_gen.class_indices.values())
class_count=len(classes)
labels=test_gen.labels
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
# Out:
# Found 3000 validated image filenames belonging to 5 classes.
# Found 826 validated image filenames belonging to 5 classes.
# Found 1656 validated image filenames belonging to 5 classes.
# test batch size:  72   test steps:  23  number of classes :  5

# %%
for i in range(0,5):
  target = classes[i]
  print(target ,train_gen.labels.count(i))
# Out:
# Doubtful 600
# Healthy 600
# Minimal 600
# Moderate 600
# Severe 600

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    for i in range(length):        
        plt.subplot(5, 5, i + 1)
        image=images[i] /255       
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=14)
        plt.axis('off')
    plt.show()
    
show_image_samples(train_gen )

# %% [markdown]
# ## Create a model using transfer learning with EfficientNetB5

# %%
img_shape=(img_size[0], img_size[1], 3)
model_name='EfficientNetB5'
base_model=tf.keras.applications.efficientnet.EfficientNetB5(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
# Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 4s 0us/step

# %% [markdown]
# ## Create a custom Keras callback to continue and optionally set LR or halt training
# The LR_ASK callback is a convenient callback that allows you to continue training for ask_epoch more epochs or to halt training.
# If you elect to continue training for more epochs you are given the option to retain the current learning rate (LR) or to
# enter a new value for the learning rate. The form of use is:
# ask=LR_ASK(model,epochs, ask_epoch) where:
#
# model is a string which is the name of your compiled model
# epochs is an integer which is the number of epochs to run specified in model.fit
# ask_epoch is an integer. If ask_epoch is set to a value say 5 then the model will train for 5 epochs.
# then the user is ask to enter H to halt training, or enter an inter value. For example if you enter 4
# training will continue for 4 more epochs to epoch 9 then you will be queried again. Once you enter an
# integer value you are prompted to press ENTER to continue training using the current learning rate
# or to enter a new value for the learning rate.
#
# At the end of training the model weights are set to the weights for the epoch that achieved the lowest validation loss

# %%
import time
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %% [markdown]
# ## Instantiate custom callback

# %%
epochs=40
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %% [markdown]
# ## Train the model
# Note unlike how you are told it is BETTER to make the base model trainable from the outset
# It will converge faster and have a lower validation losss

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 10  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/40
# 150/150 [==============================] - ETA: 0s - loss: 9.0656 - accuracy: 0.3873
#  validation loss of  7.8916 is below lowest loss, saving weights from epoch 1   as best weights
# 150/150 [==============================] - 145s 741ms/step - loss: 9.0656 - accuracy: 0.3873 - val_loss: 7.8916 - val_accuracy: 0.4092
# Epoch 2/40
# 150/150 [==============================] - ETA: 0s - loss: 6.7973 - accuracy: 0.5027
#  validation loss of  5.9009 is below lowest loss, saving weights from epoch 2   as best weights
# 150/150 [==============================] - 107s 712ms/step - loss: 6.7973 - accuracy: 0.5027 - val_loss: 5.9009 - val_accuracy: 0.5303
# Epoch 3/40
# 150/150 [==============================] - ETA: 0s - loss: 5.2264 - accuracy: 0.5843
#  validation loss of  4.7232 is below lowest loss, saving weights from epoch 3   as best weights
# 150/150 [==============================] - 107s 714ms/step - loss: 5.2264 - accuracy: 0.5843 - val_loss: 4.7232 - val_accuracy: 0.5811
# Epoch 4/40
# 150/150 [==============================] - ETA: 0s - loss: 4.1497 - accuracy: 0.6307
#  validation loss of  3.8551 is below lowest loss, saving weights from epoch 4   as best weights
# 150/150 [==============================] - 107s 714ms/step - loss: 4.1497 - accuracy: 0.6307 - val_loss: 3.8551 - val_accuracy: 0.5617
# Epoch 5/40
# 150/150 [==============================] - ETA: 0s - loss: 3.3140 - accuracy: 0.6690
#  validation loss of  3.3411 is below lowest loss, saving weights from epoch 5   as best weights
# 150/150 [==============================] - 108s 721ms/step - loss: 3.3140 - accuracy: 0.6690 - val_loss: 3.3411 - val_accuracy: 0.3886
# Epoch 6/40
# 150/150 [==============================] - ETA: 0s - loss: 2.6604 - accuracy: 0.6790
#  validation loss of  2.6278 is below lowest loss, saving weights from epoch 6   as best weights
# 150/150 [==============================] - 109s 720ms/step - loss: 2.6604 - accuracy: 0.6790 - val_loss: 2.6278 - val_accuracy: 0.5303
# Epoch 7/40
# 150/150 [==============================] - ETA: 0s - loss: 2.1198 - accuracy: 0.7167
#  validation loss of  2.1507 is below lowest loss, saving weights from epoch 7   as best weights
# 150/150 [==============================] - 107s 714ms/step - loss: 2.1198 - accuracy: 0.7167 - val_loss: 2.1507 - val_accuracy: 0.5920
# Epoch 8/40
# 150/150 [==============================] - ETA: 0s - loss: 1.7465 - accuracy: 0.7287
#  validation loss of  1.9654 is below lowest loss, saving weights from epoch 8   as best weights
# 150/150 [==============================] - 107s 715ms/step - loss: 1.7465 - accuracy: 0.7287 - val_loss: 1.9654 - val_accuracy: 0.5642
# Epoch 9/40
# 150/150 [==============================] - ETA: 0s - loss: 1.4399 - accuracy: 0.7450
#  validation loss of  1.6713 is below lowest loss, saving weights from epoch 9   as best weights
# 150/150 [==============================] - 108s 716ms/step - loss: 1.4399 - accuracy: 0.7450 - val_loss: 1.6713 - val_accuracy: 0.5714
# Epoch 10/40
# 150/150 [==============================] - ETA: 0s - loss: 1.2087 - accuracy: 0.7827
#  validation loss of  1.6616 is below lowest loss, saving weights from epoch 10  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 10
# you entered  10  Training will continue to epoch  20
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00100
# 150/150 [==============================] - 225s 2s/step - loss: 1.2087 - accuracy: 0.7827 - val_loss: 1.6616 - val_accuracy: 0.5327
# Epoch 11/40
# 150/150 [==============================] - ETA: 0s - loss: 1.0455 - accuracy: 0.7927
#  validation loss of  1.5161 is below lowest loss, saving weights from epoch 11  as best weights
# 150/150 [==============================] - 107s 715ms/step - loss: 1.0455 - accuracy: 0.7927 - val_loss: 1.5161 - val_accuracy: 0.5339
# Epoch 12/40
# 150/150 [==============================] - ETA: 0s - loss: 0.8956 - accuracy: 0.8223
#  validation loss of  1.6493 is above lowest loss of  1.5161 keeping weights from epoch 11 as best weights
# 150/150 [==============================] - 107s 712ms/step - loss: 0.8956 - accuracy: 0.8223 - val_loss: 1.6493 - val_accuracy: 0.4637
# Epoch 13/40
# 150/150 [==============================] - ETA: 0s - loss: 0.7740 - accuracy: 0.8490
#  validation loss of  1.8594 is above lowest loss of  1.5161 keeping weights from epoch 11 as best weights
# 150/150 [==============================] - 107s 712ms/step - loss: 0.7740 - accuracy: 0.8490 - val_loss: 1.8594 - val_accuracy: 0.4697
# Epoch 14/40
# 150/150 [==============================] - ETA: 0s - loss: 0.7026 - accuracy: 0.8583
#  validation loss of  1.4665 is below lowest loss, saving weights from epoch 14  as best weights
# 150/150 [==============================] - 107s 713ms/step - loss: 0.7026 - accuracy: 0.8583 - val_loss: 1.4665 - val_accuracy: 0.5617
# Epoch 15/40
# 150/150 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.8737
#  validation loss of  1.4650 is below lowest loss, saving weights from epoch 15  as best weights
# 150/150 [==============================] - 107s 715ms/step - loss: 0.6372 - accuracy: 0.8737 - val_loss: 1.4650 - val_accuracy: 0.5702
# Epoch 16/40
# 150/150 [==============================] - ETA: 0s - loss: 0.5872 - accuracy: 0.8823
#  validation loss of  1.5704 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 713ms/step - loss: 0.5872 - accuracy: 0.8823 - val_loss: 1.5704 - val_accuracy: 0.4964
# Epoch 17/40
# 150/150 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.9057
#  validation loss of  1.6324 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 714ms/step - loss: 0.5239 - accuracy: 0.9057 - val_loss: 1.6324 - val_accuracy: 0.4831
# Epoch 18/40
# 150/150 [==============================] - ETA: 0s - loss: 0.4776 - accuracy: 0.9207
#  validation loss of  1.6999 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 712ms/step - loss: 0.4776 - accuracy: 0.9207 - val_loss: 1.6999 - val_accuracy: 0.5230
# Epoch 19/40
# 150/150 [==============================] - ETA: 0s - loss: 0.4455 - accuracy: 0.9253
#  validation loss of  1.4654 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 710ms/step - loss: 0.4455 - accuracy: 0.9253 - val_loss: 1.4654 - val_accuracy: 0.5666
# Epoch 20/40
# 150/150 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.9370
#  validation loss of  1.4710 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 7
# you entered  7  Training will continue to epoch  27
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00100
# 150/150 [==============================] - 131s 874ms/step - loss: 0.4155 - accuracy: 0.9370 - val_loss: 1.4710 - val_accuracy: 0.5860
# Epoch 21/40
# 150/150 [==============================] - ETA: 0s - loss: 0.3636 - accuracy: 0.9517
#  validation loss of  1.4905 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 713ms/step - loss: 0.3636 - accuracy: 0.9517 - val_loss: 1.4905 - val_accuracy: 0.5751
# Epoch 22/40
# 150/150 [==============================] - ETA: 0s - loss: 0.3534 - accuracy: 0.9493
#  validation loss of  1.4693 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 713ms/step - loss: 0.3534 - accuracy: 0.9493 - val_loss: 1.4693 - val_accuracy: 0.5763
# Epoch 23/40
# 150/150 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.9463
#  validation loss of  1.4857 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 712ms/step - loss: 0.3648 - accuracy: 0.9463 - val_loss: 1.4857 - val_accuracy: 0.5678
# Epoch 24/40
# 150/150 [==============================] - ETA: 0s - loss: 0.3336 - accuracy: 0.9493
#  validation loss of  1.7401 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 710ms/step - loss: 0.3336 - accuracy: 0.9493 - val_loss: 1.7401 - val_accuracy: 0.5315
# Epoch 25/40
# 150/150 [==============================] - ETA: 0s - loss: 0.3476 - accuracy: 0.9480
#  validation loss of  1.5475 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 714ms/step - loss: 0.3476 - accuracy: 0.9480 - val_loss: 1.5475 - val_accuracy: 0.5605
# Epoch 26/40
# 150/150 [==============================] - ETA: 0s - loss: 0.3287 - accuracy: 0.9527
#  validation loss of  1.7152 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 714ms/step - loss: 0.3287 - accuracy: 0.9527 - val_loss: 1.7152 - val_accuracy: 0.5375
# Epoch 27/40
# 150/150 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.9597
#  validation loss of  1.8270 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 3
# you entered  3  Training will continue to epoch  30
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00100
# 150/150 [==============================] - 117s 782ms/step - loss: 0.2952 - accuracy: 0.9597 - val_loss: 1.8270 - val_accuracy: 0.4891
# Epoch 28/40
# 150/150 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.9630
#  validation loss of  1.6619 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 107s 712ms/step - loss: 0.2819 - accuracy: 0.9630 - val_loss: 1.6619 - val_accuracy: 0.5194
# Epoch 29/40
# 150/150 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.9703
#  validation loss of  1.5180 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
# 150/150 [==============================] - 108s 714ms/step - loss: 0.2613 - accuracy: 0.9703 - val_loss: 1.5180 - val_accuracy: 0.5908
# Epoch 30/40
# 150/150 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.9753
#  validation loss of  1.8282 is above lowest loss of  1.4650 keeping weights from epoch 15 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# H
# you entered  H  Training halted on epoch  30  due to user input
#
# 150/150 [==============================] - 130s 869ms/step - loss: 0.2499 - accuracy: 0.9753 - val_loss: 1.8282 - val_accuracy: 0.5472
# loading model with weights from epoch  15
# training elapsed time was 0.0 hours, 58.0 minutes, 46.13 seconds)

# %% [markdown]
# ##Define a function to plot the training data

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout    
    plt.show()
    
tr_plot(history,0)

# %% [markdown]
# ## Make Predictions on the test set
#
# Define a function which takes in a test generator and an integer test_steps¶
# and generates predictions on the test set including a confusion matric
# and a classification report

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 15s 408ms/step
# there were 666 errors in 1656 tests for an accuracy of  59.78
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#     Doubtful     0.2923    0.3615    0.3233       296
#      Healthy     0.7023    0.7199    0.7110       639
#      Minimal     0.6534    0.4049    0.5000       447
#     Moderate     0.6482    0.8924    0.7509       223
#       Severe     0.8431    0.8431    0.8431        51
#
#     accuracy                         0.5978      1656
#    macro avg     0.6279    0.6444    0.6257      1656
# weighted avg     0.6129    0.5978    0.5942      1656

# %% [markdown]
# ## combine classes
# In looking at some of the training images Isuspect there may be a wide range of choice by an individual or individuals that viewed the images and provided the labels. Thus the lower performance of the model is not surprizing. I believe their is a fundamental inconsistancy in the labelling. It would make more sense to have only 3 classes, healthy, moderate and severe. Into the new healthy class is would include the classes healthy doubtful and minimal. I would level the moderate and severe classes as they are. So lets modify the labels in the train, test and
# valid dataframes

# %%
def relabel(label_in):
    if label_in =='Healthy' or label_in == 'Doubtful' or label_in =='Minimal':
        label='Healthy'
    else:
        label=label_in
    return label


for df in [train_df, test_df, valid_df]:
    for i in range (len(df)):
        label=df['labels'].iloc[i]
        new_label=relabel(label)
        df['labels'].iloc[i]=new_label

# %%
print (train_df['labels'].value_counts())
# Out:
# Healthy     1800
# Severe       600
# Moderate     600
# Name: labels, dtype: int64

# %% [markdown]
# now trim the train dataframe to have a max of 500 images per class

# %%
max_samples=500 # since each class has more than 200 images all classes will be trimmed to have 200 images per class
min_samples=500
column='labels'
train_df= trim(train_df, max_samples, min_samples, column)
# Out:
# after trimming, the maximum samples in any class is now  500  and the minimum samples in any class is  500

# %%
batch_size=20 # We will use and EfficientetB3 model, with image size of (200, 250) this size should not cause resource error
trgen=ImageDataGenerator(horizontal_flip=True,rotation_range=20 )
t_and_v_gen=ImageDataGenerator()
msg='{0:70s} for train generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
msg='{0:70s} for valid generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
# this insures that we go through all the sample in the test set exactly once.
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
msg='{0:70s} for test generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
# from the generator we can get information we will need later
classes=list(train_gen.class_indices.keys())
class_indices=list(train_gen.class_indices.values())
class_count=len(classes)
labels=test_gen.labels
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
# Out:
# Found 1500 validated image filenames belonging to 3 classes.
# Found 826 validated image filenames belonging to 3 classes.
# Found 1656 validated image filenames belonging to 3 classes.
# test batch size:  72   test steps:  23  number of classes :  3

# %%
K.clear_session() #clear the session
tf.compat.v1.reset_default_graph()
img_shape=(img_size[0], img_size[1], 3)
model_name='EfficientNetB5'
base_model=tf.keras.applications.efficientnet.EfficientNetB5(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
# Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
epochs=40
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
new_history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 10  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/40
# 75/75 [==============================] - ETA: 0s - loss: 8.6633 - accuracy: 0.5513
#  validation loss of  7.3354 is below lowest loss, saving weights from epoch 1   as best weights
# 75/75 [==============================] - 83s 802ms/step - loss: 8.6633 - accuracy: 0.5513 - val_loss: 7.3354 - val_accuracy: 0.8535
# Epoch 2/40
# 75/75 [==============================] - ETA: 0s - loss: 6.9245 - accuracy: 0.7040
#  validation loss of  6.1830 is below lowest loss, saving weights from epoch 2   as best weights
# 75/75 [==============================] - 57s 758ms/step - loss: 6.9245 - accuracy: 0.7040 - val_loss: 6.1830 - val_accuracy: 0.8281
# Epoch 3/40
# 75/75 [==============================] - ETA: 0s - loss: 5.6400 - accuracy: 0.8147
#  validation loss of  4.9892 is below lowest loss, saving weights from epoch 3   as best weights
# 75/75 [==============================] - 57s 757ms/step - loss: 5.6400 - accuracy: 0.8147 - val_loss: 4.9892 - val_accuracy: 0.9104
# Epoch 4/40
# 75/75 [==============================] - ETA: 0s - loss: 4.6528 - accuracy: 0.8460
#  validation loss of  4.4421 is below lowest loss, saving weights from epoch 4   as best weights
# 75/75 [==============================] - 57s 755ms/step - loss: 4.6528 - accuracy: 0.8460 - val_loss: 4.4421 - val_accuracy: 0.8099
# Epoch 5/40
# 75/75 [==============================] - ETA: 0s - loss: 3.9177 - accuracy: 0.8800
#  validation loss of  3.6241 is below lowest loss, saving weights from epoch 5   as best weights
# 75/75 [==============================] - 56s 750ms/step - loss: 3.9177 - accuracy: 0.8800 - val_loss: 3.6241 - val_accuracy: 0.8995
# Epoch 6/40
# 75/75 [==============================] - ETA: 0s - loss: 3.3590 - accuracy: 0.9060
#  validation loss of  3.0912 is below lowest loss, saving weights from epoch 6   as best weights
# 75/75 [==============================] - 57s 752ms/step - loss: 3.3590 - accuracy: 0.9060 - val_loss: 3.0912 - val_accuracy: 0.9056
# Epoch 7/40
# 75/75 [==============================] - ETA: 0s - loss: 2.9042 - accuracy: 0.9093
#  validation loss of  2.6889 is below lowest loss, saving weights from epoch 7   as best weights
# 75/75 [==============================] - 57s 757ms/step - loss: 2.9042 - accuracy: 0.9093 - val_loss: 2.6889 - val_accuracy: 0.9104
# Epoch 8/40
# 75/75 [==============================] - ETA: 0s - loss: 2.4815 - accuracy: 0.9253
#  validation loss of  2.3700 is below lowest loss, saving weights from epoch 8   as best weights
# 75/75 [==============================] - 56s 750ms/step - loss: 2.4815 - accuracy: 0.9253 - val_loss: 2.3700 - val_accuracy: 0.8874
# Epoch 9/40
# 75/75 [==============================] - ETA: 0s - loss: 2.1335 - accuracy: 0.9267
#  validation loss of  1.9783 is below lowest loss, saving weights from epoch 9   as best weights
# 75/75 [==============================] - 57s 757ms/step - loss: 2.1335 - accuracy: 0.9267 - val_loss: 1.9783 - val_accuracy: 0.9286
# Epoch 10/40
# 75/75 [==============================] - ETA: 0s - loss: 1.8588 - accuracy: 0.9307
#  validation loss of  1.7246 is below lowest loss, saving weights from epoch 10  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 5
# you entered  5  Training will continue to epoch  15
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00100
# 75/75 [==============================] - 69s 923ms/step - loss: 1.8588 - accuracy: 0.9307 - val_loss: 1.7246 - val_accuracy: 0.9165
# Epoch 11/40
# 75/75 [==============================] - ETA: 0s - loss: 1.5603 - accuracy: 0.9513
#  validation loss of  1.6964 is below lowest loss, saving weights from epoch 11  as best weights
# 75/75 [==============================] - 58s 767ms/step - loss: 1.5603 - accuracy: 0.9513 - val_loss: 1.6964 - val_accuracy: 0.8232
# Epoch 12/40
# 75/75 [==============================] - ETA: 0s - loss: 1.3509 - accuracy: 0.9480
#  validation loss of  1.3818 is below lowest loss, saving weights from epoch 12  as best weights
# 75/75 [==============================] - 57s 752ms/step - loss: 1.3509 - accuracy: 0.9480 - val_loss: 1.3818 - val_accuracy: 0.8862
# Epoch 13/40
# 75/75 [==============================] - ETA: 0s - loss: 1.1587 - accuracy: 0.9520
#  validation loss of  1.2145 is below lowest loss, saving weights from epoch 13  as best weights
# 75/75 [==============================] - 58s 776ms/step - loss: 1.1587 - accuracy: 0.9520 - val_loss: 1.2145 - val_accuracy: 0.8692
# Epoch 14/40
# 75/75 [==============================] - ETA: 0s - loss: 1.0113 - accuracy: 0.9460
#  validation loss of  1.1187 is below lowest loss, saving weights from epoch 14  as best weights
# 75/75 [==============================] - 57s 752ms/step - loss: 1.0113 - accuracy: 0.9460 - val_loss: 1.1187 - val_accuracy: 0.8692
# Epoch 15/40
# 75/75 [==============================] - ETA: 0s - loss: 0.8831 - accuracy: 0.9533
#  validation loss of  1.0474 is below lowest loss, saving weights from epoch 15  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 3
# you entered  3  Training will continue to epoch  18
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00100
# 75/75 [==============================] - 66s 883ms/step - loss: 0.8831 - accuracy: 0.9533 - val_loss: 1.0474 - val_accuracy: 0.8511
# Epoch 16/40
# 75/75 [==============================] - ETA: 0s - loss: 0.7331 - accuracy: 0.9660
#  validation loss of  0.7719 is below lowest loss, saving weights from epoch 16  as best weights
# 75/75 [==============================] - 57s 752ms/step - loss: 0.7331 - accuracy: 0.9660 - val_loss: 0.7719 - val_accuracy: 0.9165
# Epoch 17/40
# 75/75 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.9680
#  validation loss of  0.6671 is below lowest loss, saving weights from epoch 17  as best weights
# 75/75 [==============================] - 57s 752ms/step - loss: 0.6257 - accuracy: 0.9680 - val_loss: 0.6671 - val_accuracy: 0.9237
# Epoch 18/40
# 75/75 [==============================] - ETA: 0s - loss: 0.5630 - accuracy: 0.9660
#  validation loss of  0.7941 is above lowest loss of  0.6671 keeping weights from epoch 17 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 3
# you entered  3  Training will continue to epoch  21
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00100
# 75/75 [==============================] - 101s 1s/step - loss: 0.5630 - accuracy: 0.9660 - val_loss: 0.7941 - val_accuracy: 0.8620
# Epoch 19/40
# 75/75 [==============================] - ETA: 0s - loss: 0.4883 - accuracy: 0.9687
#  validation loss of  0.6119 is below lowest loss, saving weights from epoch 19  as best weights
# 75/75 [==============================] - 57s 755ms/step - loss: 0.4883 - accuracy: 0.9687 - val_loss: 0.6119 - val_accuracy: 0.8971
# Epoch 20/40
# 75/75 [==============================] - ETA: 0s - loss: 0.4351 - accuracy: 0.9680
#  validation loss of  0.6904 is above lowest loss of  0.6119 keeping weights from epoch 19 as best weights
# 75/75 [==============================] - 56s 748ms/step - loss: 0.4351 - accuracy: 0.9680 - val_loss: 0.6904 - val_accuracy: 0.8438
# Epoch 21/40
# 75/75 [==============================] - ETA: 0s - loss: 0.3839 - accuracy: 0.9740
#  validation loss of  0.6297 is above lowest loss of  0.6119 keeping weights from epoch 19 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# H
# you entered  H  Training halted on epoch  21  due to user input
#
# 75/75 [==============================] - 60s 796ms/step - loss: 0.3839 - accuracy: 0.9740 - val_loss: 0.6297 - val_accuracy: 0.8705
# loading model with weights from epoch  19
# training elapsed time was 0.0 hours, 21.0 minutes, 41.10 seconds)

# %%
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 13s 426ms/step
# there were 142 errors in 1656 tests for an accuracy of  91.43
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#      Healthy     0.9801    0.9276    0.9532      1382
#     Moderate     0.6346    0.8565    0.7290       223
#       Severe     0.8723    0.8039    0.8367        51
#
#     accuracy                         0.9143      1656
#    macro avg     0.8290    0.8627    0.8396      1656
# weighted avg     0.9303    0.9143    0.9194      1656

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout    
    plt.show()
    
tr_plot(new_history,0)

# %% [markdown]
# ## Save Model

# %%
subject='knee' 
acc=str(( 1-errors/tests) * 100)
index=acc.rfind('.')
acc=acc[:index + 3]
save_id= subject + '_' + str(acc) + '.h5' 
model_save_loc=os.path.join(working_dir, save_id)
model.save(model_save_loc)
print ('model was saved as ' , model_save_loc )
# Out:
# model was saved as  ./knee_91.42.h5
